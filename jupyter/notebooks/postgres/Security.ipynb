# %% [markdown]
# ## Segurança de Dados na prática.
# Row Levels Security
#
# Leis Geral de Proteção de Dados - LGPD
# General Data Protection Regulation - GDPR
# California Consumer Privacy Act - CCPA
