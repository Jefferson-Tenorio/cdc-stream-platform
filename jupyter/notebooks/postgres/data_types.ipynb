# %% [markdown]
# | Type             | Storage  | Description                              | Range                                                                 |
# |:-----------------|:--------:|:----------------------------------------|:----------------------------------------------------------------------|
# | smallint         | 2 bytes  | small-range integer                      | -32768 to +32767                                                      |
# | integer          | 4 bytes  | typical choice for integer               | -2147483648 to +2147483647                                            |
# | bigint           | 8 bytes  | large-range integer                      | -9223372036854775808 to +9223372036854775807                          |
# | decimal          | variable | user-specified precision, exact          | up to 131072 digits before the decimal point; up to 16383 after       |
# | numeric          | variable | user-specified precision, exact          | up to 131072 digits before the decimal point; up to 16383 after       |
# | real             | 4 bytes  | variable-precision, inexact              | 6 decimal digits precision                                            |
# | double precision | 8 bytes  | variable-precision, inexact              | 15 decimal digits precision                                           |
# | smallserial      | 2 bytes  | small autoincrementing integer           | 1 to 32767                                                            |
# | serial           | 4 bytes  | autoincrementing integer                 | 1 to 2147483647                                                       |
# | bigserial        | 8 bytes  | large autoincrementing integer           | 1 to 9223372036854775807                                              |

# %%
# %%sql
# SELECT typname, typlen, typtype, typcategory
# FROM pg_catalog.pg_type
# WHERE typname IN ('int2', 'int4', 'int8', 'float4', 'float8',
#                   'text', 'varchar', 'bpchar', 'bool', 'uuid',
#                   'date', 'timestamp', 'timestamptz', 'numeric')
# ORDER BY typcategory, typname;
# Out:
#  * postgresql+psycopg2://postgres:***@postgres:5432/lab_dados
# 14 rows affected.
# [('bool', 1, 'b', 'B'),
#  ('date', 4, 'b', 'D'),
#  ('timestamp', 8, 'b', 'D'),
#  ('timestamptz', 8, 'b', 'D'),
#  ('float4', 4, 'b', 'N'),
#  ('float8', 8, 'b', 'N'),
#  ('int2', 2, 'b', 'N'),
#  ('int4', 4, 'b', 'N'),
#  ('int8', 8, 'b', 'N'),
#  ('numeric', -1, 'b', 'N'),
#  ('bpchar', -1, 'b', 'S'),
#  ('text', -1, 'b', 'S'),
#  ('varchar', -1, 'b', 'S'),
#  ('uuid', 16, 'b', 'U')]

# %%
# %%sql
# SELECT
#     typname,
#     CASE typlen
#         WHEN -1 THEN 'variável (TOAST)'
#         WHEN -2 THEN 'C-string'
#         ELSE typlen::text || ' bytes (fixo)'
#     END AS armazenamento
# FROM pg_type
# WHERE typname IN ('int2','int4','int8','float4','float8',
#                   'bool','date','time','timestamp','timestamptz',
#                   'uuid','text','varchar','numeric','jsonb')
# ORDER BY typname;
# Out:
#  * postgresql+psycopg2://postgres:***@postgres:5432/lab_dados
# 15 rows affected.
# [('bool', '1 bytes (fixo)'),
#  ('date', '4 bytes (fixo)'),
#  ('float4', '4 bytes (fixo)'),
#  ('float8', '8 bytes (fixo)'),
#  ('int2', '2 bytes (fixo)'),
#  ('int4', '4 bytes (fixo)'),
#  ('int8', '8 bytes (fixo)'),
#  ('jsonb', 'variável (TOAST)'),
#  ('numeric', 'variável (TOAST)'),
#  ('text', 'variável (TOAST)'),
#  ('time', '8 bytes (fixo)'),
#  ('timestamp', '8 bytes (fixo)'),
#  ('timestamptz', '8 bytes (fixo)'),
#  ('uuid', '16 bytes (fixo)'),
#  ('varchar', 'variável (TOAST)')]

# %%
# %%sql
# SELECT
#     c.table_name,
#     c.column_name,
#     c.data_type,
#     c.character_maximum_length,
#     c.numeric_precision,
#     c.numeric_scale,
#     c.is_nullable
# FROM information_schema.columns c
# WHERE c.table_schema = 'public'
# ORDER BY c.table_name, c.ordinal_position;
# Out:
#  * postgresql+psycopg2://postgres:***@postgres:5432/lab_dados
# 0 rows affected.
# []

# %%
# %%sql
# SELECT
#     relname AS tabela,
#     pg_size_pretty(pg_total_relation_size(relid)) AS total,
#     pg_size_pretty(pg_relation_size(relid))       AS heap,
#     pg_size_pretty(pg_indexes_size(relid))        AS indexes
# FROM pg_stat_user_tables
# ORDER BY pg_total_relation_size(relid) DESC;
# Out:
#  * postgresql+psycopg2://postgres:***@postgres:5432/lab_dados
# 2 rows affected.
# [('customers_pii', '32 kB', '0 bytes', '24 kB'),
#  ('customer_pii_operations', '16 kB', '0 bytes', '8192 bytes')]
